# %% [markdown]
# # Producing headline findings
#
# - [done] Update taxonomy file to reflect the new grouping
# - Produce standard stats across all datasets, using the same, updated taxonomy groups
#     - Check magnitude and growth for each category (past five years)
#     - Check magnitude and growth for each category (past 10 years, for low numbers)
#     - Produce stats at the granular and broader levels
# - Produce standard stats across all datasets, using intersections between broad taxonomy groups
#     - Check the same
# - Produce same stats for different countries, and compare UK (vs Europe, vs global)
# - NB: deduplicate when aggregating!

# %%
import pandas as pd
import requests
import altair as alt
import json

from discovery_child_development import PROJECT_DIR
from discovery_child_development.getters import openalex, patents
from discovery_child_development.utils import plotting_utils as pu
from discovery_child_development.utils import analysis_utils as au
from discovery_child_development.utils import altair_save_utils
from discovery_child_development.utils import openalex_utils
from discovery_child_development.getters import crunchbase

ENRICHED_DATA_DIR = PROJECT_DIR / 'outputs/enrichments'
INPUTS_DATA_DIR = PROJECT_DIR / 'inputs/data/crunchbase'

# %%
AltairSaver = altair_save_utils.AltairSaver()
# Out:
# 2024-05-24 14:31:51,983 - root - INFO - Downloading chromedriver (125.0.6422.78)...
# CHROME >= 115, using mac-arm64 as architecture identifier

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Global variables

# %%
openalex_label = "Publications"
patents_label = "Patents"

# %% [markdown]
# ### Load in the labelled data

# %%
# Patents and publications labelled data
data_df = (
    pd.read_csv(ENRICHED_DATA_DIR / 'taxonomy_cat/taxonomy_cat_predictions_filtered.csv')
    .assign(id = lambda df: df['id'].apply(lambda x: x.split('/')[-1]))
)

# Gateway to Research labelled data
gtr_metadata = pd.read_csv(ENRICHED_DATA_DIR / 'gtr_texts.csv')
gtr_data_df = (
    pd.read_csv(ENRICHED_DATA_DIR / 'taxonomy_cat/taxonomy_cat_predictions_gtr_filtered.csv')
    .assign(Dataset="UKRI")
    .assign(year=lambda df: df['start'].apply(lambda x: int(x.split('-')[0])))
    .drop(columns=['start', 'end'])
    .merge(gtr_metadata[['id', 'amount']], on='id', how='left')
    .assign(amount = lambda df: df.amount / 1000)
)

# Crunchbase labelled data
cb_data_df = (
    pd.read_csv(ENRICHED_DATA_DIR / 'crunchbase_combined_labels_checked.csv')
    # .assign(Dataset="cb")
)

# gtr_metadata_df = gtr_data_df[['id','start']].copy()
# gtr_data_df = gtr_data_df[['id', 'text', 'source', 'topics', 'year']]
# data_df = pd.concat([data_df, gtr_data_df], ignore_index=True)

# %%
data_df.head(2)
# Out:
#                  id                                               text  \
# 0    CN-107945066-A  Kindergarten intelligent control system and co...
# 1  WO-2015164890-A2  A method of promoting growth and brain develop...
#
#     source    topics
# 0  patents  robotics
# 1  patents       NaN

# %%
gtr_data_df.head(2)
# Out:
#                                      id  \
# 0  F8886352-F22C-4E4C-AFAC-14A7D8CE0FF3
# 1  96C939D9-ABA8-4436-8587-13FE39723721
#
#                                                 text   topics source  year
# 0  Strengthening health system promotion of mater...   health    gtr  2015
# 1  Understanding human cytomegalovirus latency as...  infancy    gtr  2018

# %%
cb_data_df.head(2)
# Out:
#                                      id  \
# 0  397845f1-40de-d4f2-8ce8-c0f44161a708
# 1  14905099-9ab3-72bf-6fbb-3ae8e45dd423
#
#                                                 text  \
# 0  Toys “R” Us is a toy and baby products retaile...
# 1  Babytree is an online website and platform whe...
#
#                               topics              name  \
# 0                              games  Toys R Us Iberia
# 1  parenting2, infancy, social_media          Babytree
#
#                                               cb_url  total_funding_usd  \
# 0  https://www.crunchbase.com/organization/toys-r-us       3.157000e+09
# 1   https://www.crunchbase.com/organization/babytree       1.003757e+09
#
#    num_funding_rounds last_funding_on  \
# 0                 2.0      2017-09-27
# 1                 8.0      2018-06-04
#
#                                    short_description source
# 0  Toys “R” Us is a toy and baby products retaile...     cb
# 1  Babytree is an online website and platform whe...     cb

# %%
data_df.groupby('source').size()
# Out:
# source
# openalex    38748
# patents     12486
# dtype: int64

# %% [markdown]
# ### Detection and management

# %%
# # Detection and management
# detection_df = (
#     pd.read_csv(ENRICHED_DATA_DIR / "openalex_patents_detection_labels.csv")
#     .assign(id = lambda df: df['id'].apply(lambda x: x.split('/')[-1]))
# )

data_df = (
    data_df
    # .merge(detection_df[['id', 'Detection', 'Detection_', 'Management', 'Management_']], on='id', how='left')
    # .drop_duplicates(subset='id', keep='first')
    # .drop_duplicates(subset='text', keep='first')
    .rename(columns={'source': 'Dataset'})
    .replace({'Dataset': {"openalex": openalex_label, "patents": patents_label}})    
)

# %%
# print(len(data_df))
# Out:
# 49805

# %% [markdown]
# ### Load in topic information

# %%
# Path to topic information
PATH_TO_TOPICS = PROJECT_DIR / "discovery_child_development/pipeline/labelling/taxonomy_cat/prompts/topics.json"

# Load topic information
topics_dict = json.load(open(PATH_TO_TOPICS, 'r'))
topics = list(topics_dict.keys())
print(len(topics))

topics_df = []
for topic in topics_dict:
    topics_df.append({
        'topic': topic,
        'type': topics_dict[topic]['type'],
        'subtype': topics_dict[topic]['subtype'],
        'name': topics_dict[topic]['name'],
        # 'description': topics_dict[topic]['description']
    })
topics_df = (
    pd.DataFrame(topics_df)
    .sort_values(['type', 'subtype', 'topic',])
    .reset_index(drop=True)
    .replace('Family and home', 'Parenting')
    .rename(columns={'type': 'type'})
)
# Out:
# 38

# %%
topics_df
# Out:
#               topic                    type                     subtype  \
# 0        operations  Child care & preschool                  Operations
# 1         preschool  Child care & preschool                   Preschool
# 2         cognitive  Development & learning       Cognitive development
# 3     communication  Development & learning  Communication and language
# 4              arts  Development & learning  Expressive arts and design
# 5          literacy  Development & learning                    Literacy
# 6       mathematics  Development & learning                 Mathematics
# 7         emotional  Development & learning   Personal social emotional
# 8              send  Development & learning   Special educational needs
# 9           infancy                 General                     Infancy
# 10          nontech                 General        Non-tech assessments
# 11           policy                 General                      Policy
# 12              rct                 General                        RCTs
# 13       protection                  Health            Child protection
# 14           health                  Health                      Health
# 15    mental_health                  Health               Mental health
# 16        nutrition                  Health          Nutrition & weight
# 17             oral                  Health                 Oral health
# 18         physical                  Health        Physical development
# 19         prenatal                  Health                    Prenatal
# 20            sleep                  Health                       Sleep
# 21       parenting2               Parenting                   Parenting
# 22        community                  Social                   Community
# 23        inclusion                  Social                   Inclusion
# 24           income                  Social                      Income
# 25       inequality                  Social                Inequalities
# 26    labour_market                  Social               Labour market
# 27  social_services                  Social             Social services
# 28         genetics              Technology                 Biosciences
# 29     neuroscience              Technology                 Biosciences
# 30              ai2              Technology         Data science and AI
# 31            games              Technology                       Games
# 32            ar_vr              Technology              Immersive tech
# 33         robotics              Technology              Immersive tech
# 34        wearables              Technology              Immersive tech
# 35         internet              Technology                    Internet
# 36     social_media              Technology                    Internet
# 37           mobile              Technology                      Mobile
#
#                           name
# 0                   Operations
# 1                    Preschool
# 2        Cognitive development
# 3   Communication and language
# 4   Expressive arts and design
# 5                     Literacy
# 6                  Mathematics
# 7    Personal social emotional
# 8    Special educational needs
# 9                      Infancy
# 10        Non-tech assessments
# 11                      Policy
# 12                        RCTs
# 13            Child protection
# 14                      Health
# 15               Mental health
# 16        Nutrition and weight
# 17                 Oral health
# 18        Physical development
# 19                    Prenatal
# 20                       Sleep
# 21                   Parenting
# 22                   Community
# 23                   Inclusion
# 24                      Income
# 25                Inequalities
# 26               Labour market
# 27             Social services
# 28                    Genetics
# 29                Neuroscience
# 30         Data science and AI
# 31                       Games
# 32                       AR VR
# 33                    Robotics
# 34                   Wearables
# 35                    Internet
# 36                Social media
# 37                      Mobile

# %% [markdown]
# ### Load in metadata

# %%
openalex_metadata_df = openalex.get_concepts_metadata()
patents_metadata_df = patents.get_patents_from_s3()

# %%
cb_funding_df = (
    pd.read_parquet(INPUTS_DATA_DIR / 'funding_rounds_full.parquet')
    .drop_duplicates('funding_round_id')
    .query("org_id in @cb_data_df['id'].unique()")
    .assign(year = lambda df: df.announced_on.apply(lambda x: int(x[:4])))
    .query("year >= 2013 and year <= 2024")
    .merge(cb_data_df[['id', 'text', 'topics']], left_on='org_id', right_on='id', how='left')
    .rename(columns = {"raised_amount_gbp": "amount"})
    .assign(Dataset = 'Investments')
    .assign(id = lambda df: df['funding_round_id'])
)[['id', 'text', 'Dataset', 'topics', 'year', 'country_code', 'amount']]

# %%
import ast
# data from 03_geo_analysis notebooks
openalex_extra_metadata_df = (
    pd.read_csv(ENRICHED_DATA_DIR / 'pubs_metadata_df.csv')
    .assign(country_code = lambda df: df['country_code'].apply(lambda x: ast.literal_eval(x)))
)

# %%
openalex_extra_metadata_df.head(1)
# Out:
#             id country_code  cited_by_count
# 0  W2134744704         [US]             610

# %% [markdown]
# ### Join labelled data with metadata

# %%
patents_df = (
    data_df
    .query('Dataset == "Patents"')
    .merge(
        (
            patents_metadata_df
            .rename(columns={'publication_number': 'id'})
            # .assign(year=lambda df: df['filing_date'].apply(lambda x: int(str(x)[0:4])))
            .assign(year=lambda df: df['publication_date'].apply(lambda x: int(str(x)[0:4])))
            .query('year >= 2013')
        )[['id', 'year', 'country_code']],
        on='id',
    )
)

openalex_df = (
    data_df
    .query('Dataset == "Publications"')
    .merge(
        (
            openalex_metadata_df
            .rename(columns={"openalex_id": "id"})
            .assign(id=lambda df: df['id'].apply(lambda x: x.split("/")[-1]))
            .drop_duplicates(subset=['id'])
        )[['id', 'year']]
        ,
        how='left',
        on='id'
    )
    .merge(
        openalex_extra_metadata_df,
        how='left',
        on='id'
    )
)

relevant_df = pd.concat([patents_df, openalex_df, gtr_data_df.assign(Dataset='UKRI'), cb_funding_df], ignore_index=True)

# %%
relevant_df.query("Dataset == 'Investments'").id.duplicated().sum()
# Out:
# 0

# %%
len(relevant_df)
# Out:
# 57182

# %%
relevant_df.tail()
# Out:
#                                          id  \
# 52322  66CE94D7-5CE8-462A-830C-E9E11EA2FE3D
# 52323  DCE50EED-4979-461F-809E-F51840CDC9E7
# 52324  E7D450F6-FE6C-4343-913A-E1DCEAB55224
# 52325  79032239-176B-4B40-A2A7-EBCF76AA12CF
# 52326  E0164690-9B2C-4C58-8764-FAB8FEABA520
#
#                                                     text Dataset  \
# 52322  VACCINE: Development of Novel BRSV Pre-Fusion ...    UKRI
# 52323  Understanding and Enhancing Repair of the Ear ...    UKRI
# 52324  Language Development and Disorder in Children ...    UKRI
# 52325  Developmental Differences in Cognitive Control...    UKRI
# 52326  The Smoke-free Homes Innovation Network (SHINE...    UKRI
#
#                                           topics  year country_code  \
# 52322                                    infancy  2017          NaN
# 52323                                        NaN  2019          NaN
# 52324               send, infancy, communication  2019          NaN
# 52325             cognitive, neuroscience, games  2017          NaN
# 52326  social_media, infancy, health, protection  2021          NaN
#
#        cited_by_count source
# 52322             NaN    gtr
# 52323             NaN    gtr
# 52324             NaN    gtr
# 52325             NaN    gtr
# 52326             NaN    gtr

# %%
(
    relevant_df
    # .assign(country_code = lambda df: df.country_code.apply(lambda x: ",".join(x) if isinstance(x, list) else x))
    .to_csv(ENRICHED_DATA_DIR / 'relevant_labelled_df_for_atlas.csv', index=False)
)

# %% [markdown]
# ### Prepare topic dataset

# %%
exploded_relevant_df = (
    relevant_df
    .dropna(subset=['topics'])
    .assign(topics_list=lambda df: df.topics.apply(lambda x: [x.strip() for x in x.split(",")]))
    .explode('topics_list')
    .drop_duplicates(subset=['id', 'topics_list'])
    .merge(topics_df, left_on='topics_list', right_on='topic', how='left', suffixes=('', '_'))
)

topic_counts = (
    exploded_relevant_df
    .groupby("topics_list")
    .agg(counts=("id", "count"))
    .reset_index()
)

# topics_df = (
#     topics_df_
#     .merge(topic_counts, left_on='topic', right_on='topics_list', how='left')
#     .fillna(0)
#     .sort_values(['type', 'counts'], ascending=[True, False])
#     # replace Family and home with Parenting
# )

# %%
topic_counts
# Out:
#         topics_list  counts
# 0               ai2    2705
# 1             ar_vr     178
# 2              arts    3302
# 3         cognitive    5485
# 4     communication    4038
# 5         community    3412
# 6         emotional    4920
# 7             games    5240
# 8          genetics    1555
# 9            health    9417
# 10        inclusion    3050
# 11           income    1916
# 12       inequality    4550
# 13          infancy   18852
# 14         internet     797
# 15    labour_market    1947
# 16         literacy    2283
# 17      mathematics    1920
# 18    mental_health    3539
# 19           mobile    1915
# 20     neuroscience    2818
# 21          nontech    3714
# 22         numeracy      39
# 23        nutrition    5379
# 24       operations    1736
# 25             oral     924
# 26       parenting2    2264
# 27         physical    3533
# 28           policy    5071
# 29        precshool       1
# 30         prenatal    3408
# 31        preschool    9305
# 32       protection    1780
# 33              rct    2023
# 34         robotics     851
# 35             send    2945
# 36            sleep    2054
# 37     social_media     380
# 38  social_services    5491
# 39        wearables     756

# %%
exploded_relevant_df
# Out:
#                                           id  \
# 0                             CN-107945066-A
# 1                            KR-101597453-B1
# 2                              EP-3787584-A1
# 3                              EP-3787584-A1
# 4                             US-11844731-B2
# ...                                      ...
# 135488  052b3741-5f72-4025-b7ac-5a3d282636fb
# 135489  052b3741-5f72-4025-b7ac-5a3d282636fb
# 135490  5f7035fc-e0ba-4a2f-8c4a-d7ada1fb5011
# 135491  9319615d-66d0-4ebf-bf2a-ab44288ded96
# 135492  9319615d-66d0-4ebf-bf2a-ab44288ded96
#
#                                                      text      Dataset  \
# 0       Kindergarten intelligent control system and co...      Patents
# 1       Smart sterilizer. The present invention relate...      Patents
# 2       Monitoring system for providing both visual an...      Patents
# 3       Monitoring system for providing both visual an...      Patents
# 4       Systems and methods for indicating an open por...      Patents
# ...                                                   ...          ...
# 135488  Healthy Start highlights a variety of communit...  Investments
# 135489  Healthy Start highlights a variety of communit...  Investments
# 135490  Child Care of Southwest Florida is a non-profi...  Investments
# 135491                                                NaN  Investments
# 135492                                                NaN  Investments
#
#                      topics  year country_code  cited_by_count      amount  \
# 0                  robotics  2018           CN             NaN         NaN
# 1                   infancy  2016           KR             NaN         NaN
# 2              ai2, infancy  2021           EP             NaN         NaN
# 3              ai2, infancy  2021           EP             NaN         NaN
# 4            sleep, infancy  2023           US             NaN         NaN
# ...                     ...   ...          ...             ...         ...
# 135488      health, infancy  2024          USA             NaN  797.518194
# 135489      health, infancy  2024          USA             NaN  797.518194
# 135490            preschool  2024          USA             NaN    7.975182
# 135491  games, social_media  2024          FIN             NaN         NaN
# 135492  games, social_media  2024          FIN             NaN         NaN
#
#          topics_list         topic                    type  \
# 0           robotics      robotics              Technology
# 1            infancy       infancy                 General
# 2                ai2           ai2              Technology
# 3            infancy       infancy                 General
# 4              sleep         sleep                  Health
# ...              ...           ...                     ...
# 135488        health        health                  Health
# 135489       infancy       infancy                 General
# 135490     preschool     preschool  Child care & preschool
# 135491         games         games              Technology
# 135492  social_media  social_media              Technology
#
#                     subtype                 name
# 0            Immersive tech             Robotics
# 1                   Infancy              Infancy
# 2       Data science and AI  Data science and AI
# 3                   Infancy              Infancy
# 4                     Sleep                Sleep
# ...                     ...                  ...
# 135488               Health               Health
# 135489              Infancy              Infancy
# 135490            Preschool            Preschool
# 135491                Games                Games
# 135492             Internet         Social media
#
# [135493 rows x 13 columns]

# %% [markdown]
# ## Technology trends across datasets

# %%
tech_subtypes = topics_df.query("type == 'Technology'").subtype.unique()
tech_subtypes = set(tech_subtypes).difference(['Games'])
tech_subtypes
# Out:
# {'Biosciences', 'Data science and AI', 'Immersive tech', 'Internet', 'Mobile'}

# %%
exploded_relevant_df.head(1)
# Out:
#                id                                               text  Dataset  \
# 0  CN-107945066-A  Kindergarten intelligent control system and co...  Patents
#
#      topics  year country_code  cited_by_count  amount topics_list     topic  \
# 0  robotics  2018           CN             NaN     NaN    robotics  robotics
#
#          type         subtype      name
# 0  Technology  Immersive tech  Robotics

# %%
tech_ts = (
    exploded_relevant_df 
    # remove duplicates
    .drop_duplicates(subset=['id', 'subtype'])
    .groupby(['Dataset', 'subtype', 'year'])
    .agg(
        counts = ('id', 'count'),
        amount = ('amount', 'sum')
    )
    .reset_index()
    .query("subtype in @tech_subtypes")
    # fill out every empty year with 0
    
)

# %%
topics_df.head(1)
# Out:
#         topic                    type     subtype        name
# 0  operations  Child care & preschool  Operations  Operations

# %%
(
    exploded_relevant_df
    # .query("country_code in @codes")
    .drop_duplicates(subset=['id', 'subtype'])
    .query("Dataset == 'Investments'")
    # .query("type == 'Technology'")
    .query("subtype == 'Data science and AI'")
    .groupby("year")
    .agg(
        counts = ('id', 'count'),
        amount = ('amount', 'sum')
    )
)
# Out:
#       counts        amount
# year
# 2013      33  14443.186653
# 2014      41  62695.652220
# 2015      27  20509.632282
# 2016      30   8720.261065
# 2017      28  19693.624071
# 2018      26   9410.117521
# 2019      24   9972.446156
# 2020      25  15067.384708
# 2021      19  27654.079291
# 2022      13   3853.714195
# 2023       4   2075.262486

# %%
gtr_ts_df = (
    gtr_data_df
    .query("year <= 2023")
    .groupby('year')
    .agg(
        counts = ('id', 'count'),
        amount = ('amount', 'sum')
    )
    .reset_index()
)

# %%
gtr_ts_df
# Out:
#     year  counts     amount
# 0   2013      53  37095.359
# 1   2014      64  66541.735
# 2   2015      83  28813.706
# 3   2016      74  31994.220
# 4   2017     124  35872.551
# 5   2018     125  51963.333
# 6   2019     115  60558.017
# 7   2020     152  55885.492
# 8   2021     114  62901.780
# 9   2022     100  54392.334
# 10  2023      82  58932.120

# %%
alt.Chart(gtr_ts_df).mark_line().encode(
    x='year',
    y='counts'
)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/discovery_child_development/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
alt.Chart(gtr_ts_df).mark_bar().encode(
    x='year',
    y='amount'
)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/discovery_child_development/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
cb_funding_df.head()
# Out:
#                                      id  \
# 0  b166734f-8d5a-8e26-7d6c-2b89bb387077
# 1  97e3c268-cd18-4955-a79b-48ac7a6da6fc
# 2  4e2bf2a3-2cc4-52f0-0c1e-6e867b1710ad
# 3  f5124fa5-ba64-9e4d-f4f2-098769c5170e
# 4  c1a13a8c-438d-4369-7ab6-f5c2cb71fff5
#
#                                                 text      Dataset  \
# 0  Case Commons is a non-profit advising child we...  Investments
# 1  OTTOs barnmat sales and development of fresh b...  Investments
# 2  ComfTech design and produce sensing garments e...  Investments
# 3                                                NaN  Investments
# 4                                                NaN  Investments
#
#                  topics  year country_code   amount
# 0  social_services, ai2  2013          USA      NaN
# 1    nutrition, infancy  2013          SWE      NaN
# 2       health, infancy  2013          ITA      NaN
# 3     preschool, mobile  2013          FRA  2445.15
# 4    mobile, parenting2  2013          USA      NaN

# %%
codes = ['USA', 'GBR']
ts_df = (
    cb_funding_df
    # .query("country_code in @codes")
    .groupby(['year'])
    .agg(
        counts = ('id', 'count'),
        amount = ('amount', 'sum')
    )
    .reset_index()
)
ts_df
# Out:
#     year  counts        amount
# 0   2013     319  7.230400e+05
# 1   2014     361  6.667436e+05
# 2   2015     430  1.768044e+06
# 3   2016     500  1.687468e+06
# 4   2017     493  3.746280e+06
# 5   2018     477  1.883202e+06
# 6   2019     529  1.461742e+06
# 7   2020     419  1.529270e+06
# 8   2021     510  3.646953e+06
# 9   2022     374  3.188832e+06
# 10  2023     375  9.171587e+05
# 11  2024      68  3.080741e+05

# %%
alt.Chart(ts_df).mark_line().encode(
    x='year',
    y='counts'
)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/discovery_child_development/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
tech_ts.query("Dataset == 'Investments'")
# Out:
#          Dataset              subtype  year  counts         amount
# 0    Investments          Biosciences  2013       2    7497.140161
# 1    Investments          Biosciences  2014       3       0.000000
# 2    Investments          Biosciences  2015       3      35.962500
# 3    Investments          Biosciences  2016       6  169723.587602
# 4    Investments          Biosciences  2017       3     232.098098
# 5    Investments          Biosciences  2018       3      75.139258
# 6    Investments          Biosciences  2019       2     899.681776
# 7    Investments          Biosciences  2020       1     403.351026
# 8    Investments          Biosciences  2021       3     838.382209
# 9    Investments          Biosciences  2022       4    4709.950386
# 10   Investments          Biosciences  2023       2    1660.545704
# 43   Investments  Data science and AI  2013      33   14443.186653
# 44   Investments  Data science and AI  2014      41   62695.652220
# 45   Investments  Data science and AI  2015      27   20509.632282
# 46   Investments  Data science and AI  2016      30    8720.261065
# 47   Investments  Data science and AI  2017      28   19693.624071
# 48   Investments  Data science and AI  2018      26    9410.117521
# 49   Investments  Data science and AI  2019      24    9972.446156
# 50   Investments  Data science and AI  2020      25   15067.384708
# 51   Investments  Data science and AI  2021      19   27654.079291
# 52   Investments  Data science and AI  2022      13    3853.714195
# 53   Investments  Data science and AI  2023       4    2075.262486
# 89   Investments       Immersive tech  2013      15   33167.127516
# 90   Investments       Immersive tech  2014      17   31663.813132
# 91   Investments       Immersive tech  2015      24   26430.324210
# 92   Investments       Immersive tech  2016      14    5039.621079
# 93   Investments       Immersive tech  2017      14    4491.292785
# 94   Investments       Immersive tech  2018       9     444.836205
# 95   Investments       Immersive tech  2019      14    2914.093692
# 96   Investments       Immersive tech  2020       3     346.620280
# 97   Investments       Immersive tech  2021       5    4590.831559
# 125  Investments             Internet  2013      23    7287.412976
# 126  Investments             Internet  2014      21   27186.681247
# 127  Investments             Internet  2015      23   89667.060253
# 128  Investments             Internet  2016      18    9052.415535
# 129  Investments             Internet  2017      16    4595.602038
# 130  Investments             Internet  2018      13   15021.254739
# 131  Investments             Internet  2019      12   12400.626476
# 132  Investments             Internet  2020       8     602.792094
# 133  Investments             Internet  2021       9   16742.349154
# 134  Investments             Internet  2022       8   12409.694414
# 135  Investments             Internet  2024       1       0.000000
# 178  Investments               Mobile  2013      69   36263.435669
# 179  Investments               Mobile  2014      53   89263.775484
# 180  Investments               Mobile  2015      56  103448.432463
# 181  Investments               Mobile  2016      51   15111.927362
# 182  Investments               Mobile  2017      44   27160.334591
# 183  Investments               Mobile  2018      30   12057.430249
# 184  Investments               Mobile  2019      29   23277.985295
# 185  Investments               Mobile  2020      24    4390.752710
# 186  Investments               Mobile  2021      28   36593.729888
# 187  Investments               Mobile  2022      15   11215.018298
# 188  Investments               Mobile  2023      10    2873.219318
# 189  Investments               Mobile  2024       1       0.000000

# %% [markdown]
# ## Publications and patents data

# %% [markdown]
# ### Number of documents per dataset

# %%
# Number of papers and patents about detection and management
fraction_detection_df = (
    relevant_df
    .groupby(["Dataset"])
    .agg(
        n=('id', 'count'),
    #     n_detection=('Detection_', 'sum'),
    #     n_management=('Management_', 'sum'),
    )
    # .assign(
    #     fraction_detection = lambda df: df['n_detection'] / df['n'],
    #     fraction_management = lambda df: df['n_management'] / df['n'],
    # )
    .reset_index()
)
# Turn 
fraction_detection_df
# Out:
#         Dataset      n
# 0       Patents  12486
# 1  Publications  38748
# 2          UKRI   1093

# %%
# Chart with number of documents per dataset
fig = (
    alt.Chart(fraction_detection_df)
    .mark_bar()
    .encode(
        x=alt.X('n:Q', title=''),
        y=alt.Y('Dataset:N', title='', sort='-x'),
        color=alt.Color('Dataset:N', title=None, legend=None),
        tooltip=['Dataset', 'n',]
    )
)
fig = pu.configure_titles(pu.configure_plots(fig), "Number of documents per dataset")

# %%
fig
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/discovery_child_development/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
n_publications = fraction_detection_df.loc[fraction_detection_df.Dataset=="Publications", "n"].iloc[0]
n_patents = fraction_detection_df.loc[fraction_detection_df.Dataset=="Patents", "n"].iloc[0]
print(f"Number of publications: {n_publications}")
print(f"Number of patents: {n_patents}")
print(f"Ratio of publications to patents: {n_publications/n_patents:.2f}")
# Out:
# Number of publications: 38271
# Number of patents: 11534
# Ratio of patents to publications: 3.32

# %%
savename = 'number_of_documents_per_dataset'
AltairSaver.save(fig, savename)

# %% [markdown]
# ### Number of documents over time

# %% [markdown]
# #### Get baseline stats for normalisation

# %%
# Publications baseline
openalex_baseline = (
    openalex_utils.get_publications_count_per_year(start_year=2013, end_year=2024)
    .assign(Dataset="Publications")
)

# %%
openalex_baseline.head()
# Out:
#    year  total_counts       Dataset
# 0  2013       9181464  Publications
# 1  2014       9560130  Publications
# 2  2015       9778972  Publications
# 3  2016      10039026  Publications
# 4  2017       9921088  Publications

# %%
# Patents baseline
patents_baseline = pd.DataFrame(json.load(open("total_patents.json", "r")))
patents_baseline = (
    patents_baseline
    .assign(Dataset="Patents")
    .rename(columns={"total_publications": "total_counts", "publication_year": "year"})
    .astype({"year": int, "total_counts": int})
)

# Combined baseline
baseline_df = pd.concat([openalex_baseline, patents_baseline], ignore_index=True)

# %%
au.ts_magnitude_growth_(
    ts_df = (
        openalex_baseline
        .query("year < 2024")
    ),
    year_start = 2019,
    year_end = 2023   
)
# Out:
# /Users/karlis.kanders/Documents/code/discovery_child_development/discovery_child_development/utils/analysis_utils.py:716: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   magnitude = time_series.set_index("year").loc[year_start:year_end, :].mean()
# /Users/karlis.kanders/Documents/code/discovery_child_development/discovery_child_development/utils/analysis_utils.py:693: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Dataset'], dtype='object')
#   df_ma = timeseries_df.rolling(window, min_periods=1).mean().drop("year", axis=1)
#               magnitude    growth
# total_counts  9998997.6 -3.237519

# %%
au.ts_magnitude_growth_(
    ts_df = (
        patents_baseline
        .query("year < 2024")
    ),
    year_start = 2019,
    year_end = 2023   
)
# Out:
# /Users/karlis.kanders/Documents/code/discovery_child_development/discovery_child_development/utils/analysis_utils.py:716: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   magnitude = time_series.set_index("year").loc[year_start:year_end, :].mean()
# /Users/karlis.kanders/Documents/code/discovery_child_development/discovery_child_development/utils/analysis_utils.py:693: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Dataset'], dtype='object')
#   df_ma = timeseries_df.rolling(window, min_periods=1).mean().drop("year", axis=1)
#               magnitude     growth
# total_counts  7572871.2  31.192759

# %% [markdown]
# ### Number of documents per year

# %%
counts_df = (
    relevant_df
    # .query("country_code != 'CN'")
    .groupby(['Dataset', 'year'])
    .agg(counts=('id', 'count'))
    .reset_index()
    .merge(
        baseline_df,
        on=['year', 'Dataset'],
        how='left'
    )    
    .assign(
        # counts = lambda df: df['counts'] / 1e6,
        # total_counts = lambda df: df['total_counts'] / 1e6,
        fraction = lambda df: df['counts'] / df['total_counts'],
        percentage = lambda df: df['fraction'] * 100,
    )
)

# Normalise counts in each source by year 2013
counts_normalised_df = (
    counts_df
    .merge(
        counts_df.query('year == 2013').rename(columns={'fraction': 'fraction_2013'})[['Dataset', 'fraction_2013']],
        on='Dataset',
        how='left'
    )
    .assign(
        normalised_fraction = lambda df: df['fraction'] / df['fraction_2013']
    )
)

# %%
counts_df
# Out:
#          Dataset  year  counts  total_counts  fraction  percentage
# 0        Patents  2013     499     4271238.0  0.000117    0.011683
# 1        Patents  2014     565     4459288.0  0.000127    0.012670
# 2        Patents  2015     948     4856237.0  0.000195    0.019521
# 3        Patents  2016    1029     5152383.0  0.000200    0.019971
# 4        Patents  2017    1107     5566320.0  0.000199    0.019887
# 5        Patents  2018    1298     6297186.0  0.000206    0.020612
# 6        Patents  2019    1387     6472541.0  0.000214    0.021429
# 7        Patents  2020    1502     7336249.0  0.000205    0.020474
# 8        Patents  2021    1578     8455856.0  0.000187    0.018662
# 9        Patents  2022    1389     8122074.0  0.000171    0.017102
# 10       Patents  2023    1096     7477636.0  0.000147    0.014657
# 11       Patents  2024      88      660824.0  0.000133    0.013317
# 12  Publications  2013    2707     9181464.0  0.000295    0.029483
# 13  Publications  2014    2995     9560130.0  0.000313    0.031328
# 14  Publications  2015    3151     9778972.0  0.000322    0.032222
# 15  Publications  2016    3560    10039026.0  0.000355    0.035462
# 16  Publications  2017    3532     9921088.0  0.000356    0.035601
# 17  Publications  2018    3874     9920319.0  0.000391    0.039051
# 18  Publications  2019    3946    10168331.0  0.000388    0.038807
# 19  Publications  2020    3623    10788490.0  0.000336    0.033582
# 20  Publications  2021    3673     9848031.0  0.000373    0.037297
# 21  Publications  2022    3561     9503596.0  0.000375    0.037470
# 22  Publications  2023    3770     9686540.0  0.000389    0.038920
# 23  Publications  2024     356     3092164.0  0.000115    0.011513
# 24          UKRI  2013      53           NaN       NaN         NaN
# 25          UKRI  2014      64           NaN       NaN         NaN
# 26          UKRI  2015      83           NaN       NaN         NaN
# 27          UKRI  2016      74           NaN       NaN         NaN
# 28          UKRI  2017     124           NaN       NaN         NaN
# 29          UKRI  2018     125           NaN       NaN         NaN
# 30          UKRI  2019     115           NaN       NaN         NaN
# 31          UKRI  2020     152           NaN       NaN         NaN
# 32          UKRI  2021     114           NaN       NaN         NaN
# 33          UKRI  2022     100           NaN       NaN         NaN
# 34          UKRI  2023      82           NaN       NaN         NaN
# 35          UKRI  2024       6           NaN       NaN         NaN
# 36          UKRI  2026       1           NaN       NaN         NaN

# %%
import importlib
importlib.reload(pu);

# %%
fig_title = "Documents by year"
fig_subtitle = ""

fig = pu.ts_smooth(
    (
        counts_normalised_df
        .query('year < 2024')
    ),
    ["Publications", "Patents"],
    variable= "counts",
    variable_title = "",
    category_column = "Dataset",
    width = 300,
    height = 150,
    legend_orient='right',
)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle)
fig
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/discovery_child_development/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
n_2013 = counts_normalised_df.query("Dataset == 'Publications' and year==2013").counts.iloc[0]
n_2023 = counts_normalised_df.query("Dataset == 'Publications' and year==2023").counts.iloc[0]
growth = (n_2023 - n_2013) / n_2013
print(f"Number of publications in 2013: {n_2013}")
print(f"Number of publications in 2023: {n_2023}")
print(f"Growth in publications: {growth:.2f}")

# %%
savename = 'documents_by_year'
AltairSaver.save(fig, savename)

# %%
fig_title = "Percentage of documents by year"
fig_subtitle = ["Normalised with respect to the total number of publications/patents"]

fig = pu.ts_smooth(
    (
        counts_normalised_df
        .query('year < 2024')
    ),
    ["Publications", "Patents"],
    variable= "percentage",
    variable_title = "",
    category_column = "Dataset",
    width = 300,
    height = 150,
    legend_orient='right',
)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle)
fig

# %%
savename = 'percentage_documents_by_year'
AltairSaver.save(fig, savename)

# %% [markdown]
# ## Detection vs management

# %%
n_management = relevant_df.Management_.sum()
n_detection = relevant_df.Detection_.sum()
n = len(relevant_df)

print(f"Number of documents about detection: {n_detection}")
print(f"Number of documents about management: {n_management}")

print(f"Fraction of documents about detection: {n_detection/n:.2f}")
print(f"Fraction of documents about management: {n_management/n:.2f}")

# %%
n_both = len(relevant_df.query("Detection_ == 1 and Management_ == 1"))
print(f"Number of documents about both detection and management: {n_both}")
print(f"Fraction of documents about both detection and management: {n_both/n:.2f}")

# %%
# Number of documents per Dataset that are about detection or management
detection_management_df = (
    relevant_df
    .groupby(['Dataset'])
    .agg(
        n=('id', 'count'),
        Detection=('Detection_', 'sum'),
        Management=('Management_', 'sum'),
    )
    .assign(
        fraction_detection = lambda df: df['Detection'] / df['n'],
        fraction_management = lambda df: df['Management'] / df['n'],
    )
    .reset_index()
)
detection_management_df

# %%
detection_management_df

# %%
# a bar chart with the number of documents about detection and management for each dataset
fig_title = "Number of documents about detection or management"
fig_df = (
    detection_management_df
    # make it a long dataframe
    .melt(id_vars=['Dataset', 'n'], var_name='Type', value_name='Count')
    .query('Type in ["Detection", "Management"]')    
)

fig = (
    alt.Chart(fig_df)
    .mark_bar()
    .encode(
        x=alt.X('Count:Q', title=''),
        y=alt.Y('Type:N', title='', sort='-x'),
        color=alt.Color('Dataset:N', title=''),
        tooltip=['Dataset', 'Count', 'Type']
    )
)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, "")
fig

# %%
savename = 'detection_management_documents'
AltairSaver.save(fig, savename)

# %% [markdown]
# ## Topics

# %%
topics_counts = (
    exploded_relevant_df
    .groupby('topics_list')
    .agg(counts=('id', 'count'))
    .reset_index()
    .merge(topics_df[['topic', 'Type', 'name']], left_on='topics_list', right_on='topic', how='left')
    .drop(columns=['topics_list'])
    .sort_values(['Type', 'counts'], ascending=[True, False])
)

topics_pubs_counts = (
    exploded_relevant_df
    .query('Dataset == "Publications"')
    .groupby('topics_list')
    .agg(counts=('id', 'count'))
    .reset_index()
    .merge(topics_df[['topic', 'Type', 'name']], left_on='topics_list', right_on='topic', how='left')
    .drop(columns=['topics_list'])
)

topics_patent_counts = (
    exploded_relevant_df
    .query('Dataset == "Patents"')
    .groupby('topics_list')
    .agg(counts=('id', 'count'))
    .reset_index()
    .merge(topics_df[['topic', 'Type', 'name']], left_on='topics_list', right_on='topic', how='left')
    .drop(columns=['topics_list'])
)

topics_counts_datasets = (
    pd.concat([
        topics_pubs_counts.assign(Dataset='Publications'),
        topics_patent_counts.assign(Dataset='Patents'),
    ], ignore_index=True)
)
# topics_counts = (
#     topics_counts
#     .merge(topics_pubs_counts, on=['topic', 'Type', 'name'], how='left', suffixes=('', '_pubs'))
#     .merge(topics_patent_counts, on=['topic', 'Type', 'name'], how='left', suffixes=('', '_patents'))
#     .fillna(0)
#     .sort_values(['Type', 'counts'], ascending=[True, False])
# )

# %%
# Stacked bar chart
fig_title = "Number of documents by topic"
fig_subtitle = ""

sort_order = topics_counts.name.to_list()

fig = (
    alt.Chart(topics_counts_datasets, height=500)
    .mark_bar()
    .encode(
        x=alt.X('counts:Q', title=''),
        # sort according to the dataframe sort order
        y=alt.Y('name:N', title='', sort=sort_order),
        color=alt.Color('Dataset:N', title=''),
        tooltip=['name', 'counts', 'Dataset']
    )
)

# axis on top as well
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle)
fig

# %%
savename = 'number_of_documents_by_topic'
AltairSaver.save(fig, savename)

# %% [markdown]
# ## Overall stats

# %%
df_patent_vs_openalex = (
    exploded_relevant_df
    .query("year >= 2013 and year < 2024")
    .groupby(['topics_list', 'source'])
    .agg(counts=('id', 'count'))
    .reset_index()
    .merge(topics_df[['topic', 'type', 'name']], left_on='topics_list', right_on='topic', how='left')
    .drop(columns='topics_list')
)

# %%
n_patents = len(
    relevant_df
    .query('year >= 2013 and year < 2024')
    .query('source == "patents"')
)

n_openalex = len(
    relevant_df
    .query('year >= 2013 and year < 2024')
    .query('source == "openalex"')
)

# %%
# pivot the table so that values in source column become columns and counts are the values
df_patent_vs_openalex_pivot = (
    df_patent_vs_openalex
    .pivot_table(index=['type', 'name'], columns='source', values='counts', fill_value=0)
    .reset_index()
    .assign(
        patents_normalised=lambda df: df['patents'] / n_patents,
        openalex_normalised=lambda df: df['openalex'] / n_openalex
    )
    .assign(
        difference=lambda df: df['openalex_normalised'] - df['patents_normalised']
    )
)
df_patent_vs_openalex_pivot

# %%
# plot a scatterplot with difference on x-axis and topic name on y-axis and sort by y-axis values
alt.Chart(
    df_patent_vs_openalex_pivot,
    width=500
).mark_circle(size=100).encode(
    x='difference:Q',
    y=alt.Y('name:N', sort='-x'),
    color='type:N',
    # size='openalex_normalised:Q'
)

# %% [markdown]
# ## Co-occurrences

# %%
coocc_df = (
    exploded_relevant_df
    .groupby("id")
    .agg(topic_list = ("topics_list", list))
    .reset_index()
)

# function to count all pairs of topics, use the topics_df unique topics, and coocc_df for topics in each document
# return a dataframe with index and columns as topics and values as counts
def get_cooccurrences(topics_df, coocc_df):
    cooccurrences = pd.DataFrame(index=topics_df['topic'], columns=topics_df['topic']).fillna(0)
    for topic_list in coocc_df['topic_list']:
        for i, topic1 in enumerate(topic_list):
            for j, topic2 in enumerate(topic_list):
                if i != j:
                    cooccurrences.loc[topic1, topic2] += 1
    return cooccurrences

matrix = get_cooccurrences(topics_df, coocc_df)

# %%
matrix.index.name = 'topic1'

# %%
# turn matrix into long format
matrix_long = (
    matrix
    .stack()
    .reset_index()
    .rename(columns={0: 'counts', 'topic': 'topic2'})
    .merge(topics_df[['topic', 'name']], left_on='topic1', right_on='topic').rename(columns={'name': 'name1'}).drop(columns='topic')
    .merge(topics_df[['topic', 'name']], left_on='topic2', right_on='topic').rename(columns={'name': 'name2'}).drop(columns='topic')    
)
matrix_long

# %%
(
    matrix_long
    .to_csv("cooccurrences.csv", index=False)
)

# %%
# visualise the matrix using a heatmap
# sort using a specified order
sort_order = topics_df.topic.to_list()
alt.Chart(
    matrix_long,
    width=500,
    height=500,
).mark_rect().encode(
    x=alt.X('name1:N', sort=sort_order),
    y=alt.Y('name2:N', sort=sort_order),
    color='counts:Q',
    tooltip=['name1', 'name2', 'counts']
)

# %%
# normalise each row by the sum of the row
matrix_normalised = matrix.div(matrix.sum(axis=1), axis=0)
# turn matrix into long format
matrix_long_normalised = (
    matrix_normalised
    .stack()
    .reset_index()
    .rename(columns={0: 'counts', 'topic': 'topic2'})
    .merge(topics_df[['topic', 'name']], left_on='topic1', right_on='topic').rename(columns={'name': 'name1'}).drop(columns='topic')
    .merge(topics_df[['topic', 'name']], left_on='topic2', right_on='topic').rename(columns={'name': 'name2'}).drop(columns='topic')     
)

# %%
# visualise the matrix using a heatmap
# sort using a specified order
sort_order = topics_df.topic.to_list()
alt.Chart(
    matrix_long_normalised,
    width=500,
    height=500,
).mark_rect().encode(
    x=alt.X('name1:N', sort=sort_order),
    y=alt.Y('name2:N', sort=sort_order),
    color='counts:Q',
    tooltip=['topic1', 'topic2', 'counts']
)

# %% [markdown]
# ## Co-occurrences of specific topics

# %%
matrix_long.head()

# %%
types = ['Area of learning', 'Health', 'Development', 'Social', 'General']
topic = "ai2"
df = (
    matrix_long
    .query("topic1 == 'ai2'")
    .merge(topics_df[['topic', 'Type']], left_on='topic2', right_on='topic')
    .drop(columns='topic')
    .rename(columns={'Type': 'Type2'})
    .query("Type2 in @types")
)
df

# %%
fig = alt.Chart(
    df,
    width=300,
    height=400,
).mark_bar().encode(
    y=alt.Y('name2:N', sort='-x', title=''),
    x=alt.X('counts:Q', title=''),
    color=alt.Color('Type2:N', legend=alt.Legend(title='Type')),
    tooltip=['name2', 'counts']
)

fig = pu.configure_titles(pu.configure_plots(fig), "Applications of AI", "Number of documents tagged with AI and other topics")
fig

# %%
savename = 'applications_of_ai'
AltairSaver.save(fig, savename)

# %%
topic = "mobile"
df = (
    matrix_long
    .query("topic1 == @topic")
    .merge(topics_df[['topic', 'Type']], left_on='topic2', right_on='topic')
    .drop(columns='topic')
    .rename(columns={'Type': 'Type2'})
    .query("Type2 in @types")
)
fig = alt.Chart(
    df,
    width=300,
    height=400,
).mark_bar().encode(
    y=alt.Y('name2:N', sort='-x', title=''),
    x=alt.X('counts:Q', title=''),
    color=alt.Color('Type2:N', legend=alt.Legend(title='Type')),
    tooltip=['name2', 'counts']
)

fig = pu.configure_titles(pu.configure_plots(fig), "Applications of AI", "Number of documents tagged with AI and other topics")
fig

# %%
savename = 'applications_of_mobile'
AltairSaver.save(fig, savename)

# %%
types = ['Area of learning', 'Health', 'Development', 'Social', 'General', 'Innovation']
topic = "parenting2"
df = (
    matrix_long
    .query("topic1 == @topic")
    .merge(topics_df[['topic', 'Type']], left_on='topic2', right_on='topic')
    .drop(columns='topic')
    .rename(columns={'Type': 'Type2'})
    .query("Type2 in @types")
)
fig = alt.Chart(
    df,
    width=300,
    height=500,
).mark_bar().encode(
    y=alt.Y('name2:N', sort='-x', title=''),
    x=alt.X('counts:Q', title=''),
    color=alt.Color('Type2:N', legend=alt.Legend(title='Type')),
    tooltip=['name2', 'counts']
)

fig = pu.configure_titles(pu.configure_plots(fig), "Overlaps with Parenting category", "Number of documents tagged with Parenting and other topics")
fig

# %%
savename = 'applications_of_parenting'
AltairSaver.save(fig, savename)

# %%
types = ['Area of learning', 'Health', 'Development', 'Social', 'General', 'Innovation']
topic = "income"
df = (
    matrix_long
    .query("topic1 == @topic")
    .merge(topics_df[['topic', 'Type']], left_on='topic2', right_on='topic')
    .drop(columns='topic')
    .rename(columns={'Type': 'Type2'})
    .query("Type2 in @types")
)
fig = alt.Chart(
    df,
    width=300,
    height=500,
).mark_bar().encode(
    y=alt.Y('name2:N', sort='-x', title=''),
    x=alt.X('counts:Q', title=''),
    color=alt.Color('Type2:N', legend=alt.Legend(title='Type')),
    tooltip=['name2', 'counts']
)

fig = pu.configure_titles(pu.configure_plots(fig), "Overlaps with Income", "Number of documents tagged with Income and other topics")
fig

# %%
savename = 'applications_of_income'
AltairSaver.save(fig, savename)

# %% [markdown]
# ## Co-occurences over time

# %%
coocc_time_df = (
    exploded_relevant_df
    .groupby(["id", "year"])
    .agg(topic_list = ("topics_list", list))
    .reset_index()
)

# %%
def get_cooccurrences_growth(topic1):
    topics2 = topics_df.topic.to_list()
    start_period = [2014, 2018]
    end_period = [2019, 2023]

    overlap_growth = []
    for topic in topics2:
        df = (
            coocc_time_df
            .assign(
                cooccurs = lambda df: df['topic_list'].apply(lambda x: topic1 in x and topic in x)
            )
            .groupby('year')
            .agg(counts=('cooccurs', 'sum'))
            .reset_index()
        )
        # sum the counts for the two periods
        sum_start_period = df.query("year >= @start_period[0] and year <= @start_period[1]").counts.sum()
        sum_end_period = df.query("year >= @end_period[0] and year <= @end_period[1]").counts.sum()
        growth_period  = (sum_end_period - sum_start_period) / sum_start_period
        overlap_growth.append({
            'topic': topic,
            'sum_start_period': sum_start_period,
            'sum_end_period': sum_end_period,
            'growth': growth_period
        })
    return pd.DataFrame(overlap_growth)

# %%
topics_of_interest = ["preschool", "literacy", "mathematics", "communication"]
cooc_growth_df = (
    get_cooccurrences_growth("ai2")
    .sort_values('growth', ascending=False)
)
df_ai2 = cooc_growth_df.query("topic in @topics_of_interest")

# %%
topics_of_interest = ["preschool", "literacy", "mathematics", "communication"]
cooc_growth_df = (
    get_cooccurrences_growth("mobile")
    .sort_values('growth', ascending=False)
)
df_mobile = cooc_growth_df.query("topic in @topics_of_interest")

# %%
coo_growth_df_ = (
    pd.concat([df_ai2.assign(topic1="AI"), df_mobile.assign(topic1="Mobile")], ignore_index=True)
    .assign(
        category = lambda df: df.topic1 + ' + ' + df.topic,
        magnitude = lambda df: df.sum_start_period + df.sum_end_period
    )
)
coo_growth_df_

# %%
fig_title = "AI, Mobile and areas of learning"
fig_subtitle = "Growth and total number of documents, 2014-2023"

fig = (
    alt.Chart(
        coo_growth_df_,
    )
    .mark_point()
    .encode(
        # add title
        x=alt.X('magnitude:Q', axis=alt.Axis(title='Number of documents')),
        # add percentages to the growth
        y=alt.Y('growth:Q', axis=alt.Axis(format='%'), title='Growth'),
        text='category:N',
        # color='Type',
        # tooltip=['category', 'magnitude', alt.Tooltip('growth', format='.2%')]
    )
    .properties(
        width=350,
        height=350  
    )
)

labels = fig.mark_text(
    align='left',
    baseline='middle',
    dx=7
).encode(
    text='category:N'
)

# Add a dashed line for zero growth
zero_growth = alt.Chart(pd.DataFrame({'zero': [0]})).mark_rule(color='black', strokeDash=[3,3]).encode(y='zero')

fig = (
    (fig + labels + zero_growth)
)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle).configure_axis(grid=False)
fig

# %%
savename = "ai_mobile_areas_of_learning"
# AltairSaver.save(fig, savename)

# %%
topic1 = "mobile"
topic = "parenting2"
df = (
    coocc_time_df
    .assign(
        cooccurs = lambda df: df['topic_list'].apply(lambda x: topic1 in x and topic in x)
    )
    .query("cooccurs")
    .merge(relevant_df[['id', 'Dataset', 'text']], how='left', on='id')
    .sort_values('year', ascending=False)
)

# %%
pd.set_option('display.max_colwidth', None)
# df.query("Dataset == 'Patents'")
# df

# %%
(
    get_cooccurrences_growth("parenting2")
    .sort_values('growth', ascending=False)
)

# %%
(
    get_cooccurrences_growth("income")
    .sort_values('growth', ascending=False)
)

# %% [markdown]
# ## Magnitude and growth

# %%
# # Total baseline
# total_baseline_df = (
#     baseline_df
#     .groupby('year')
#     .agg(total_counts=('total_counts', 'sum'))
#     .reset_index()
# )

# %%
def get_timeseries(df: pd.DataFrame, normalise: bool=False, baseline_df: pd.DataFrame=None) -> pd.DataFrame:
    df = (
        df
        .groupby(['year'])
        .agg(counts=('id', 'count'))
        .reset_index()
    )
    # add 0 for empty years
    years = list(range(2013, 2024))
    df = (
        df
        .merge(
            pd.DataFrame({'year': years}),
            on='year',
            how='right'
        )
        .fillna(0)
    )
    # normalise by baseline
    if normalise:
        df = (
            df
            .merge(
                baseline_df,
                on='year',
                how='left'
            )
            .assign(
                fraction = lambda df: df['counts'] / df['total_counts'],
                percentage = lambda df: df['fraction'] * 100
            )
        )
    return df.sort_values('year')


def get_timeseries_charts(df: pd.DataFrame, topics_dict: dict, baseline_df: pd.DataFrame=None) -> pd.DataFrame:
    timeseries = []
    for topic in topics_dict:
        t_df = get_timeseries(
            df.query("topics_list == @topic"), 
            normalise=True, 
            baseline_df=baseline_df
        ).assign(category=topic)
        timeseries.append(t_df)
    return pd.concat(timeseries, ignore_index=True)


# Calculate magnitude and growth for each category
# Magnitude is the average across past five years (2019-2023)
# Growth is the average growth rate across past five years (2019-2023)
# Growth is calculated by taking 3-year moving average and then comparing 2019 and 2023
def calculate_magnitude_growth(timeseries_df: pd.DataFrame) -> pd.DataFrame:
    magnitude_growth = []
    for category in timeseries_df['category'].unique():
        category_df = timeseries_df.query('category == @category').sort_values('year')
        magnitude = category_df.query('year >= 2019 and year <= 2023')['counts'].sum()
        magnitude_normalised = category_df.query('year >= 2019 and year <= 2023')['fraction'].mean()
        # calculate moving average with sliding window
        category_df['moving_average'] = category_df['fraction'].rolling(window=3).mean()
        growth = (category_df.query('year == 2023')['moving_average'].values[0] - category_df.query('year == 2019')['moving_average'].values[0]) / category_df.query('year == 2019')['moving_average'].values[0]
        magnitude_growth.append({
            'category': category,
            'magnitude': magnitude,
            'magnitude_normalised': magnitude_normalised,
            'growth': growth
        })
    return pd.DataFrame(magnitude_growth)

# def timeseries_chart(df: pd.DataFrame, title: str) -> alt.Chart:
#     return (
#         alt.Chart(
#             df,
#             width=500)
#         .mark_line()
#         .encode(
#             x='year:O',
#             y='counts:Q'
#         )
#         .properties(
#             title=title
#         )
#     )

# %%
au.ts_magnitude_growth_(
    ts_df = (
        counts_normalised_df
        .query("Dataset == 'Publications' and year < 2024")
    ),
    year_start = 2019,
    year_end = 2023   
)

# %%
au.ts_magnitude_growth_(
    ts_df = (
        counts_normalised_df
        .query("Dataset == 'Patents' and year < 2024")
    ),
    year_start = 2019,
    year_end = 2023   
)

# %% [markdown]
# ### Publications

# %%
pubs_df = exploded_relevant_df.query("Dataset == 'Publications'")
pubs_timeseries_df = get_timeseries_charts(pubs_df, topics_dict, openalex_baseline)
pubs_magnitude_growth_df = (
    calculate_magnitude_growth(pubs_timeseries_df)
    .merge(
        topics_df,
        left_on='category',
        right_on='topic',
        how='left'
    )
    .drop(columns=['topic'])
)

# %%
# category_df = pubs_timeseries_df.query('category == "infancy"').sort_values('year')
# au.ts_magnitude_growth_(category_df, 2019, 2023)

# %%
pubs_magnitude_growth_df.head()

# %%
# # Plot the technology timeseries with AI, Mobile, AR/VR, Social media
# # include = ['ai2', 'mobile', 'ar_vr', 'social_media']
# include = topics_df.query('type == "Development"').topic.to_list()
# fig = (
#     alt.Chart(
#         timeseries_df.query('category in @include').query('year < 2024'),
#         width=500)
#     .mark_line()
#     .encode(
#         x='year:O',
#         y='counts:Q',
#         color='category',
#         tooltip='category'
#     )
#     .properties(
#         title='Document counts (patents and publications)'
#     )
# )
# fig.interactive()

# %%
# Plot a scatter plot of magnitude and growth
# Display labels next to the scatter points and remove grid lines
fig_title = "Publication magnitude and growth by topic"
fig_subtitle = "Growth and total number of publications, 2019-2023"

fig = (
    alt.Chart(
        pubs_magnitude_growth_df,
    )
    .mark_point()
    .encode(
        # add title
        x=alt.X('magnitude:Q', axis=alt.Axis(title='Number of documents')),
        # add percentages to the growth
        y=alt.Y('growth:Q', axis=alt.Axis(format='%'), title='Growth'),
        text='category:N',
        color='Type',
        tooltip=['category', 'magnitude', alt.Tooltip('growth', format='.2%')]
    )
    .properties(
        width=400,
        height=400  
    )
)

labels = fig.mark_text(
    align='left',
    baseline='middle',
    dx=7
).encode(
    text='name:N'
)

# Add a dashed line for zero growth
zero_growth = alt.Chart(pd.DataFrame({'zero': [0]})).mark_rule(color='black', strokeDash=[3,3]).encode(y='zero')

fig = (
    (fig + labels + zero_growth)
)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle).configure_axis(grid=False)

# %%
fig

# %%
savename = 'publication_magnitude_growth'
AltairSaver.save(fig, savename)

# %%
# Plot x-axis as growth, size as magnitude, and y axis as topic
fig_title = "Publication magnitude and growth by topic"
fig_subtitle = "Growth and total number of publications, 2019-2023"

def growth_figure(pubs_magnitude_growth_df):
    fig = (
        alt.Chart(
            pubs_magnitude_growth_df,
        )
        .mark_circle()
        .encode(
            # add title
            x=alt.X('growth:Q', axis=alt.Axis(format='%', labelAlign='center'), title='Growth'),
            # don't show the axis
            y=alt.Y('name:N', title='Topic', sort='-x', axis=None),
            size=alt.Size('magnitude:Q', title='Number of documents', legend=None),
            color=alt.Color('Type', legend=alt.Legend(title='', orient='bottom-right')),
            tooltip=['name', 'magnitude', alt.Tooltip('growth', format='.2%')]
        )
        .properties(
            width=400,
            height=400  
        )
    )

    # Labels but same size for all
    fig_labels_ = (
        alt.Chart(
            pubs_magnitude_growth_df,
        )
        .mark_circle()
        .encode(
            # add title
            x=alt.X('growth:Q', axis=alt.Axis(format='%'), title='Growth'),
            y=alt.Y('name:N', title='Topic', sort='-x'),
        )
    )
    fig_labels = (
        fig_labels_.mark_text(
            align='left',
            baseline='middle',
            dx=7
        ).encode(
            text='name:N'
        )
    )

    # Add a dashed vertical line for zero growth
    zero_growth = alt.Chart(pd.DataFrame({'zero': [0]})).mark_rule(color='black', strokeDash=[3,3]).encode(x='zero')

    fig = fig + fig_labels + zero_growth
    return fig

fig = growth_figure(pubs_magnitude_growth_df)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle)#.configure_axis(grid=False)
fig

# %%
savename = 'publication_growth'
AltairSaver.save(fig, savename)

# %% [markdown]
# ### Time series

# %%
fig = pu.ts_smooth(
    pubs_timeseries_df,
    ["internet", "health", "mental_health", "genetics", "rct", "nutrition"],
    variable= "percentage",
    variable_title = "",
    category_column = "category",
    width = 400,
    height = 200,
    legend_orient='right',
)
fig = pu.configure_titles(pu.configure_plots(fig), "Percentage of documents by year", "Normalised with respect to the total number of publications")
fig

# %% [markdown]
# ### Patents

# %%
patents_df = (
    exploded_relevant_df
    .query("Dataset == 'Patents'")
    # .query("country_code != 'CN'")
)
patents_timeseries_df = get_timeseries_charts(patents_df, topics_dict, patents_baseline)
patents_magnitude_growth_df = (
    calculate_magnitude_growth(patents_timeseries_df)
    .merge(
        topics_df,
        left_on='category',
        right_on='topic',
        how='left'
    )
    .drop(columns=['topic'])
    .query('magnitude >= 25')
)

# %%
# Plot a scatter plot of magnitude and growth
# Display labels next to the scatter points and remove grid lines
fig_title = "Patent magnitude and growth by topic"
fig_subtitle = "Growth and total number of patents, 2019-2023"

fig = (
    alt.Chart(
        patents_magnitude_growth_df,
    )
    .mark_point()
    .encode(
        # add title
        x=alt.X('magnitude:Q', axis=alt.Axis(title='Number of documents')),
        # add percentages to the growth
        y=alt.Y('growth:Q', axis=alt.Axis(format='%'), title='Growth'),
        text='category:N',
        color='Type',
        tooltip=['category', 'magnitude', alt.Tooltip('growth', format='.2%')]
    )
    .properties(
        width=400,
        height=400  
    )
)

labels = fig.mark_text(
    align='left',
    baseline='middle',
    dx=7
).encode(
    text='name:N'
)

# Add a dashed line for zero growth
zero_growth = alt.Chart(pd.DataFrame({'zero': [0]})).mark_rule(color='black', strokeDash=[3,3]).encode(y='zero')

fig = (
    (fig + labels + zero_growth)
)
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle).configure_axis(grid=False)

# %%
fig

# %%
savename = 'patent_magnitude_growth'
AltairSaver.save(fig, savename)

# %%
baseline_growth = alt.Chart(pd.DataFrame({'zero': [-0.17731658]})).mark_rule(color='black', strokeDash=[3,3]).encode(x='zero')
fig = growth_figure(patents_magnitude_growth_df) + baseline_growth
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle)#.configure_axis(grid=False)
fig

# %%
savename = 'patent_growth'
AltairSaver.save(fig, savename)

# %% [markdown]
# ### Patents (without China)

# %%
patents_df = (
    exploded_relevant_df
    .query("Dataset == 'Patents'")
    .query("country_code != 'CN'")
)
patents_timeseries_df = get_timeseries_charts(patents_df, topics_dict, patents_baseline)
patents_magnitude_growth_df = (
    calculate_magnitude_growth(patents_timeseries_df)
    .merge(
        topics_df,
        left_on='category',
        right_on='topic',
        how='left'
    )
    .drop(columns=['topic'])
    .query('magnitude >= 25')
)

# %%
baseline_growth = alt.Chart(pd.DataFrame({'zero': [-0.17731658]})).mark_rule(color='black', strokeDash=[3,3]).encode(x='zero')
fig = growth_figure(patents_magnitude_growth_df) + baseline_growth
fig = pu.configure_titles(pu.configure_plots(fig), fig_title, fig_subtitle)#.configure_axis(grid=False)
fig

# %% [markdown]
# ## Ad-hoc checks

# %%
# Coronavirus mentions
keywords = ["covid", "coronavirus"]
hits_df = (
    relevant_df[['id', 'year', 'text']]
    .copy()
    .assign(hits = lambda df: df.text.str.lower().str.contains("|".join(keywords)))
    .query('hits == True')
)
hits_counts_df = hits_df.groupby('year').agg(counts=('id', 'count')).reset_index().assign(cat="cat")

pu.ts_smooth(
    hits_counts_df.query('year < 2024'),
    ["cat"],
    variable= "counts",
    variable_title = "",
    category_column = "cat",
    width = 300,
    height = 150,
    legend_orient='right',
)

# %%
hits_df

# %% [markdown]
# ## Mock use cases: AI

# %%
# Calculate embeddings, reduce dimensionality, cluster and plot the embeddings
import discovery_child_development.utils.cluster_analysis_utils as cau
from discovery_child_development import logger
alt.data_transformers.disable_max_rows()
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

SEED = 42
UMAP_PARAMS = {
    "n_components": 50,
    "n_neighbors": 10,
    "min_dist": 0.5,
    "spread": 0.5,
}

# %%
data_df = get_hits(relevant_df, keywords['AI'])

# %%
# Create embeddings for the unique concepts
embeddings = model.encode(data_df["text"].tolist(), show_progress_bar=True)

# %%
# Reduce dimensionality of the embeddings
embeddings_50 = cau.umap_reducer(embeddings, UMAP_PARAMS, random_umap_state=SEED)

# Run with an arbitrary number of clusters
kmeans_labels = cau.kmeans_clustering(
    embeddings_50,
    kmeans_params={"init": "k-means++", "n_clusters": 6, "random_state": SEED},
)

# Reduce original vectors to 2D for plotting
embeddings_2d = cau.reduce_to_2D(embeddings, random_state=SEED)

# %%
# Add 2D vectors into the dataframe for plotting
clusters_df = (
    data_df.copy()
    .reset_index(drop=True)
    .assign(
        cluster=kmeans_labels,
        x=embeddings_2d[:, 0],
        y=embeddings_2d[:, 1],
    )
)

# %%
import importlib
importlib.reload(cau)

# %%
CLUSTER_SUMMARY_MESSAGE = "Here are the most central documents of cluster. \
Describe what kind of innovations is this cluster capturing, in 2 sentences. \
\n\n##Abstracts\n\n {} \n\n##Description (2 short sentences)"

cluster_descriptions = cau.describe_clusters_with_gpt(
    cluster_df=clusters_df,
    embeddings=embeddings,
    n_central=30,
    gpt_message=CLUSTER_SUMMARY_MESSAGE,
)
cluster_names_dict = cau.generate_cluster_names_with_gpt(
    cluster_descriptions=cluster_descriptions,
)
cluster_summaries = pd.DataFrame(
    data={
        "cluster": cluster_names_dict.keys(),
        "cluster_name": cluster_names_dict.values(),
        "cluster_description": cluster_descriptions,
    }
)
pd.set_option("display.max_colwidth", None)
cluster_summaries

# %%
clusters_df_final = (
    clusters_df.copy().merge(
    cluster_summaries, left_on="cluster", right_on="cluster", how="left")
    .assign(url = lambda df: [prepare_url(row.id, row.source) for i, row in df.iterrows()])
)

fig = (
    alt.Chart(clusters_df_final[['x', 'y', "source", "cluster", "cluster_name", "cluster_description", "id", "text", "url"]])
    .mark_circle()
    .encode(
        x="x",
        y="y",
        color=alt.Color("cluster_name:N", legend=alt.Legend(title="cluster name")),
        tooltip=["cluster", "cluster_name","text"],
        # change symbol type depending on source
        shape="source",
        # add url
        href = 'url:N'
    )
    .properties(width=800, height=600)
    .interactive()
)

# create labels for cluster centroids
# calculate the centroid of each cluster
# add the labels to the plot
centroids_df = (
    clusters_df_final
    .groupby('cluster')
    .agg(x=('x', 'mean'), y=('y', 'mean'))
    .reset_index()
)
# add names
centroids_df = centroids_df.merge(cluster_summaries[['cluster', 'cluster_name']], on='cluster', how='left')

labels = (
    alt.Chart(centroids_df)
    .mark_text(align='left', baseline='middle', dx=7)
    .encode(
        x='x:Q',
        y='y:Q',
        # increase font size
        text=alt.Text('cluster_name:N')
    )
)

(
    (fig + labels)
    .configure_axis(grid=False)
)

# %%
fig.save(PROJECT_DIR / 'outputs/enrichments/AI_test_dataset.html')

# %%
clusters_df_final.to_csv(PROJECT_DIR / 'outputs/enrichments/AI_test_dataset.csv', index=False)

# %% [markdown]
# ## Check categorised data

# %%
topics = [
    "ai2",
    "ar_vr",
    "mobile",
    "income",
    "parenting",
]

# %%
LABELS_DIR = PROJECT_DIR / 'outputs/labels/taxonomy_cat'
PATH_TO_TOPICS = PROJECT_DIR / "discovery_child_development/pipeline/labelling/taxonomy_cat/prompts/topics.json"
topics = json.load(open(PATH_TO_TOPICS, 'r'))

# %%
detection_df = pd.read_csv(DATA_DIR / 'openalex_patents_detection_labels.csv')

# %%
ENRICHED_DATA_DIR = PROJECT_DIR / 'outputs/enrichments'
labelled_df = pd.read_csv(ENRICHED_DATA_DIR / 'taxonomy_cat/taxonomy_cat_predictions_all.csv')

# %%
relevant_labelled_df = (
    relevant_df
    .assign(
        id = lambda df: df['id'].apply(lambda x: x.split('/')[-1])
    )
    .merge(labelled_df, on='id', how='left')
    .assign(topic_name = lambda df: df['topic'].apply(lambda x: topics[x]['name'] if pd.notnull(x) else None))
    # .drop("prediction", axis=1)
)

# %%
relevant_labelled_df.groupby(["source", "topic_name"]).size()

# %%
(
    relevant_labelled_df
    .query("topic == 'ai2'")
    .prediction

# %%
def get_timeseries_charts(df: pd.DataFrame, keywords: dict) -> alt.Chart:
    keyword_timeseries = []
    for keyword, keywords_list in keywords.items():
        keyword_hits_df = get_hits(df, keywords_list)
        keyword_timeseries.append(get_timeseries(keyword_hits_df).assign(category=keyword))
    return pd.concat(keyword_timeseries, ignore_index=True)

timeseries_df = get_timeseries_charts(relevant_df, keywords)

# %% [markdown]
# ## Check each category and output a cluster map

# %%
# Calculate embeddings, reduce dimensionality, cluster and plot the embeddings
import discovery_child_development.utils.cluster_analysis_utils as cau
from discovery_child_development import logger
alt.data_transformers.disable_max_rows()
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

SEED = 42
UMAP_PARAMS = {
    "n_components": 50,
    "n_neighbors": 10,
    "min_dist": 0.5,
    "spread": 0.5,
}

# %%
VECTORS_PATH = "data/outputs/vectors/"
VECTORS_FILE = "sentence_vectors_384_labelled.parquet"
from discovery_child_development.getters.openalex import get_sentence_embeddings
from discovery_child_development import S3_BUCKET

# Embeddings from all-MiniLM-L6-v2
embeddings_all = (
    get_sentence_embeddings(
        s3_bucket=S3_BUCKET, filepath=VECTORS_PATH, filename=VECTORS_FILE, id="id",
    )
    .reset_index()
    .assign(id=lambda df: df['id'].apply(lambda x: x.split('/')[-1]))
    # restore index
    # .set_index("id")
)

# %%
topic = "ai2"
topic_df = (
    relevant_labelled_df.query('topic == @topic')
    .merge(
        embeddings_all,
        on='id',
        how='left'
    )
)
embeddings = topic_df.miniLM_384_vector.values.tolist()

# %%
# Reduce dimensionality of the embeddings
embeddings_50 = cau.umap_reducer(embeddings, UMAP_PARAMS, random_umap_state=SEED)

# Run with an arbitrary number of clusters
kmeans_labels = cau.kmeans_clustering(
    embeddings_50,
    kmeans_params={"init": "k-means++", "n_clusters": 6, "random_state": SEED},
)

# Reduce original vectors to 2D for plotting
embeddings_2d = cau.reduce_to_2D(embeddings, random_state=SEED)

# %%
# Add 2D vectors into the dataframe for plotting
clusters_df = (
    topic_df.copy()
    .reset_index(drop=True)
    .assign(
        cluster=kmeans_labels,
        x=embeddings_2d[:, 0],
        y=embeddings_2d[:, 1],
    )
)

# %%
import numpy as np

CLUSTER_SUMMARY_MESSAGE = "Here are the most central documents of cluster. \
Describe what kind of innovations is this cluster capturing, in 2 sentences. \
\n\n##Abstracts\n\n {} \n\n##Description (2 short sentences)"

cluster_descriptions = cau.describe_clusters_with_gpt(
    cluster_df=clusters_df,
    embeddings=np.array(embeddings),
    n_central=30,
    gpt_message=CLUSTER_SUMMARY_MESSAGE,
)
cluster_names_dict = cau.generate_cluster_names_with_gpt(
    cluster_descriptions=cluster_descriptions,
)
cluster_summaries = pd.DataFrame(
    data={
        "cluster": cluster_names_dict.keys(),
        "cluster_name": cluster_names_dict.values(),
        "cluster_description": cluster_descriptions,
    }
)
pd.set_option("display.max_colwidth", None)
cluster_summaries

# %%
clusters_df_final = (
    clusters_df.copy().merge(
    cluster_summaries, left_on="cluster", right_on="cluster", how="left")
    .assign(url = lambda df: [prepare_url(row.id, row.source) for i, row in df.iterrows()])
)

fig = (
    alt.Chart(clusters_df_final[['x', 'y', "source", "cluster", "cluster_name", "cluster_description", "id", "text", "url"]])
    .mark_circle()
    .encode(
        x="x",
        y="y",
        color=alt.Color("cluster_name:N", legend=alt.Legend(title="cluster name")),
        tooltip=["cluster", "cluster_name","text"],
        # change symbol type depending on source
        shape="source",
        # add url
        href = 'url:N'
    )
    .properties(width=800, height=600)
    .interactive()
)

# create labels for cluster centroids
# calculate the centroid of each cluster
# add the labels to the plot
centroids_df = (
    clusters_df_final
    .groupby('cluster')
    .agg(x=('x', 'mean'), y=('y', 'mean'))
    .reset_index()
)
# add names
centroids_df = centroids_df.merge(cluster_summaries[['cluster', 'cluster_name']], on='cluster', how='left')

labels = (
    alt.Chart(centroids_df)
    .mark_text(align='left', baseline='middle', dx=7)
    .encode(
        x='x:Q',
        y='y:Q',
        # increase font size
        text=alt.Text('cluster_name:N')
    )
)

(
    (fig + labels)
    .configure_axis(grid=False)
)

# %% [markdown]
# ## Prepare data for exploration

# %%
detection_df = pd.read_csv(ENRICHED_DATA_DIR / 'openalex_patents_detection_labels.csv')

# %%
from discovery_child_development.utils.utils import prepare_url

# %%
relevant_labelled_df.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/karlis.kanders/Documents/code/discovery_child_development/discovery_child_development/analysis/initial_results/01_initial_labels.ipynb Cell 159 line 1
# ----> <a href='vscode-notebook-cell:/Users/karlis.kanders/Documents/code/discovery_child_development/discovery_child_development/analysis/initial_results/01_initial_labels.ipynb#Y312sZmlsZQ%3D%3D?line=0'>1</a> relevant_labelled_df.head(1)
#
# NameError: name 'relevant_labelled_df' is not defined

# %%
relevant_labelled_df.query("topic == 'ai2'").query("prob_relevant >= 0.5").groupby("source").size()

# %%
titles_df = (
    pd.concat([
        patents_metadata_df[['publication_number', 'title']].rename(columns={'publication_number': 'id'}),
        (
            openalex_metadata_df
            .rename(columns={'openalex_id': 'id'})
            .assign(id = lambda df: df['id'].apply(lambda x: x.split('/')[-1]))
        )[['id', 'title']]
    ], ignore_index=True)
    .drop_duplicates(['id'])
)

export_df = (
    relevant_labelled_df
    .copy()
    .drop('predictions', axis=1)
    .assign(url = [prepare_url(row.id, row.source) for index, row in relevant_labelled_df.iterrows()])
    .merge(
        titles_df,
        on='id',
        how='left'
    )
# )[['id', 'title', 'text', 'year', 'source', 'url', 'Detection', 'Management', 'Detection_', 'Management_']]
)[['id', 'title', 'text', 'year', 'source', 'url', 'topic', 'topic_name', 'prob_relevant', 'prediction']]

# %%
detection_df = (
    pd.read_csv(ENRICHED_DATA_DIR / "openalex_patents_detection_labels.csv")
    .rename(columns ={
        "Detection": "prob_detection",
        "Management": "prob_management",
        "Detection_": "Detection",
        "Management_": "Management"
    })
    .assign(id = lambda df: df['id'].apply(lambda x: x.split('/')[-1]))
)

# %%
topics_df = (
    export_df
    .query("prediction >= 0.8")
    .groupby(["id"])
    .agg(
        topic=("topic", list),
        topic_name=("topic_name", list),
    )
)
export_df = (
    export_df[['id', 'title', 'text', 'year', 'source', 'url']]
    .drop_duplicates("id")
    .merge(
        topics_df,
        on="id",
        how="left"
    )
    .merge(
        detection_df[["id", "prob_detection", "prob_management", "Detection", "Management"]],
        on="id",
        how="left"
    )
)

# %%
# export_df.to_csv(PROJECT_DIR / 'outputs/enrichments/relevant_documents.csv', index=False)

# %%
# remove altair row limit
alt.data_transformers.disable_max_rows()

# plot scatter with detection and management values
fig = (
    alt.Chart(
        export_df,
        width=500)
    .mark_point(opacity=0.2)
    .encode(
        x='Detection:Q',
        y='Management:Q',
        color='source',
        tooltip=['id', 'title', 'text', 'year', 'url']
    )
    .properties(
        title='Detection and Management scores'
    )
    .interactive()
)

# %%
export_df.to_csv('relevant_documents.csv', index=False)

# %%
export_df.info()

# %%
ensemble_dict = {
    0: "0/5",
    0.2: "1/5",
    0.4: "2/5",
    0.6: "3/5",
    0.8: "4/5",
    1: "5/5"
}

topic = "mobile"
topic_df_ = (
    export_df[export_df.topic.astype(str).str.contains(topic)]
    .drop(["topic", "topic_name"], axis=1)
    .merge(relevant_labelled_df[['id', 'prediction', 'prob_relevant', 'topic', 'topic_name']].query("topic == @topic"),on='id', how='left') 
    .assign(ensemble = lambda df: df['prediction'].apply(lambda x: ensemble_dict[x]))
    .drop('prediction', axis=1)
)
topic_df_.to_csv(f"relevant_documents_{topic}.csv", index=False)

# %%
topic_df_
