# %%
from discovery_child_development import PROJECT_DIR, S3_BUCKET
from nesta_ds_utils.loading_saving import S3
import pandas as pd

ENRICHED_DATA_DIR = PROJECT_DIR / 'outputs/enrichments'
PATH_TO_DATASET = ENRICHED_DATA_DIR / 'openalex_patents_relevance_labels_only_relevant.csv'

# %%
patent_relevance = S3.download_obj(
    S3_BUCKET,
    f"data/outputs/binary_classifier/patents_openalex_random_sample_2019_labelled.csv",
    download_as="dataframe",
)
# Out:
# 2024-05-31 17:17:45,670 - botocore.credentials - INFO - Found credentials in environment variables.

# %%
patent_relevance = patent_relevance.query("predictions == 1").assign(source = "patents")

# %%
len(patent_relevance)
# Out:
# 26178

# %%
patent_relevance.to_csv(ENRICHED_DATA_DIR / 'patents_relevance_labels_only_relevant.csv', index=False)

# %%
patent_relevance.head(1)
# Out:
#     Unnamed: 0              id  \
# 18          18  CN-212289393-U
#
#                                                  text  predictions
# 18  Baby carriage. A baby carriage comprises a rea...            1

# %%
patent_relevance_old = pd.read_csv(PATH_TO_DATASET).query("source == 'patents'")

# %%
len(patent_relevance_old)
# Out:
# 12486

# %%
patent_relevance_old.head(1)
# Out:
#    Unnamed: 0              id  \
# 0          11  CN-107945066-A
#
#                                                 text  predictions   source
# 0  Kindergarten intelligent control system and co...            1  patents
