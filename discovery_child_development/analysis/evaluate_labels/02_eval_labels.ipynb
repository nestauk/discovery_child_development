# %%
from discovery_child_development.utils.jsonl_utils import load_jsonl
from discovery_child_development import PROJECT_DIR

import pandas as pd

EVALS_DIR = PROJECT_DIR / 'outputs/labels/evals_data'
LABELS_RELEVANCE = EVALS_DIR / "relevance_labels_eval_annotated.jsonl"
LABELS_DETECTION_MANAGEMENT = EVALS_DIR / "detection_labels_eval_annotated.jsonl"
LABELS_TAXONOMY = EVALS_DIR / "taxonomy_labels_eval_annotated.jsonl"

# %%
def get_data(path):
    columns = ['id', 'prediction', 'accept', '_annotator_id', 'correct']
    return (
        pd.DataFrame(load_jsonl(path))
        .assign(accept = lambda df: df['accept'].apply(lambda x: x[0]))
        .assign(correct = lambda df: df['prediction'] == df['accept'])
        )[columns]
    # annotations by annotator
    # compare prediction vs accept label

def get_taxonomy_data(path):
    columns = ['id', 'prediction', 'answer', '_annotator_id', 'correct']
    return (
        pd.DataFrame(load_jsonl(path))
        .assign(correct = lambda df: df['answer'] == 'accept')
        )[columns]

# %%
def get_annotator_counts(data_df):
    return (
        data_df
        .groupby('_annotator_id')
        .agg(counts = ('id', 'count'))
        .reset_index()
    )

# %%
def get_accuracy(data_df):
    return (
        data_df
        .groupby('prediction')
        .agg(accuracy = ('correct', 'mean'))
        .reset_index()
    )

# %%
def check_labels(data_df, category):
    return (
        data_df
        .query("prediction == @category")
        .groupby('accept')
        .agg(counts = ('id', 'count'))
        .reset_index()
    )

def check_taxonomy_labels(data_df, category):
    return (
        data_df
        .query("prediction == @category")
        .groupby('answer')
        .agg(counts = ('id', 'count'))
        .reset_index()
    )

# %% [markdown]
# ## Relevance labels

# %%
data_df = get_data(LABELS_RELEVANCE)
get_annotator_counts(data_df)
# Out:
#            _annotator_id  counts
# 0  relevance_data-karlis      73
# 1  relevance_data-laurie      23
# 2   relevance_data-rosie      50

# %%
get_accuracy(data_df)
# Out:
#       prediction  accuracy
# 0   Not-relevant  0.895833
# 1  Not-specified  0.620000
# 2       Relevant  0.895833

# %%
check_labels(data_df, 'Not-specified')
# Out:
#           accept  counts
# 0            ???       2
# 1   Not-relevant       1
# 2  Not-specified      31
# 3       Relevant      16

# %% [markdown]
# ## Detection and management labels

# %%
data_df = get_data(LABELS_DETECTION_MANAGEMENT)
get_annotator_counts(data_df)
# Out:
#             _annotator_id  counts
# 0   detection_data-karlis      34
# 1   detection_data-laurie      80
# 2  detection_data-natalie      32
# 3    detection_data-rosie      54

# %%
get_accuracy(data_df)
# Out:
#    prediction  accuracy
# 0        Both      0.64
# 1   Detection      0.72
# 2  Management      0.74
# 3        None      0.70

# %%
check_labels(data_df, 'Both')
# Out:
#        accept  counts
# 0         ???       2
# 1        Both      32
# 2   Detection       4
# 3  Management      10
# 4        None       2

# %%
check_labels(data_df, 'Detection')
# Out:
#        accept  counts
# 0         ???       2
# 1        Both       5
# 2   Detection      36
# 3  Management       5
# 4        None       2

# %%
check_labels(data_df, 'Management')
# Out:
#        accept  counts
# 0         ???       6
# 1        Both       2
# 2  Management      37
# 3        None       5

# %% [markdown]
# ## Taxonomy labels

# %%
data_df = get_taxonomy_data(LABELS_TAXONOMY)
get_accuracy(data_df).sort_values('accuracy', ascending=False)
# Out:
#                     prediction  accuracy
# 28                 Oral health  0.969697
# 36                       Sleep  0.960784
# 34                        RCTs  0.920000
# 14                      Income  0.920000
# 26        Nutrition and weight  0.900000
# 22               Mental health  0.896552
# 12                      Health  0.880000
# 10                       Games  0.860000
# 18               Labour market  0.846154
# 20                 Mathematics  0.840000
# 0                        AR VR  0.833333
# 41        Technology (general)  0.800000
# 16                     Infancy  0.780000
# 7          Data science and AI  0.780000
# 23                      Mobile  0.775510
# 31                      Policy  0.774194
# 21                       Media  0.742857
# 25        Non-tech assessments  0.724138
# 3        Cognitive development  0.720000
# 17                    Internet  0.709677
# 39               Special needs  0.700000
# 35                    Robotics  0.693878
# 24                Neuroscience  0.687500
# 19                    Literacy  0.640000
# 30                    Physical  0.620000
# 15                Inequalities  0.615385
# 42                   Wearables  0.612903
# 8   Expressive arts and design  0.580000
# 33                   Preschool  0.560000
# 32                    Prenatal  0.540000
# 37                Social media  0.533333
# 13                   Inclusion  0.500000
# 27                  Operations  0.488889
# 38             Social services  0.461538
# 9              Family and home  0.460000
# 29   Personal social emotional  0.460000
# 11                    Genetics  0.448980
# 6                         Data  0.408163
# 4   Communication and language  0.400000
# 2             Child protection  0.320000
# 5                    Community  0.256410
# 40         Statistical methods  0.230769
# 1         Assessment (general)  0.180000

# %%
len(data_df)
# Out:
# 1806

# %%
get_annotator_counts(data_df)
# Out:
#            _annotator_id  counts
# 0     taxonomy_data-jess      25
# 1   taxonomy_data-karlis    1472
# 2   taxonomy_data-laurie     250
# 3  taxonomy_data-natalie      59

# %%
check_taxonomy_labels(data_df, 'Communication and language')
# Out:
#    answer  counts
# 0  accept      20
# 1  ignore       2
# 2  reject      28

# %%
data_df.groupby('prediction').agg(counts = ('id', 'count')).sort_values('counts', ascending=False)
# Out:
#                             counts
# prediction
# Sleep                           51
# Technology (general)            50
# Health                          50
# Nutrition and weight            50
# Prenatal                        50
# Preschool                       50
# Assessment (general)            50
# Mathematics                     50
# Literacy                        50
# Infancy                         50
# Special needs                   50
# Personal social emotional       50
# Physical                        50
# Games                           50
# Family and home                 50
# Expressive arts and design      50
# Data science and AI             50
# Communication and language      50
# Cognitive development           50
# Child protection                50
# Genetics                        49
# Robotics                        49
# Data                            49
# Mobile                          49
# Neuroscience                    48
# Operations                      45
# Community                       39
# Inclusion                       38
# AR VR                           36
# Media                           35
# Oral health                     33
# Policy                          31
# Internet                        31
# Wearables                       31
# Social media                    30
# Non-tech assessments            29
# Mental health                   29
# Labour market                   26
# Social services                 26
# Inequalities                    26
# Statistical methods             26
# RCTs                            25
# Income                          25
